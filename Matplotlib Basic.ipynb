# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x= list(range(0,10))
y= list(range(10,20))
plt.plot(x,y)

# %%
a= [0,-100,25,66]
b= [0,3,4,5]
plt.plot(a,b)

# %%
plt.axis([-50, 80,2,8])
plt.plot(a,b)

# %%
plt.title("triangle")
plt.xlabel("arraya")
plt.ylabel("arrayb")
plt.xticks((-100,-75, -50, -25, 0, 25, 50), ('s','h','r','e','y','a','V'))
plt.plot(a,b, color="red")

# %%
plt.hist(a)
plt.hist(b)
# Out:
# (array([1., 0., 0., 0., 0., 0., 1., 0., 1., 1.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)
